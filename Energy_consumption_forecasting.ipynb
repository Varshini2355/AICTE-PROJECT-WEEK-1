# %% [markdown]
# # ***ENERGY CONSUMPTION FORECASTING***
#
# # ***PROBLEM STATEMENT***
#  Accurate forecasting of energy consumption is essential to reduce cost,prevent energy wastage,and enable sustainable power management
#
# # ***Importing required libraries***

# %%
import numpy as np
import pandas as pd
import pandas as df # Corrected typo: 'dataframe' changed to 'pandas'
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from datetime import datetime
import joblib

# %% [markdown]
# # ***Dataset Overview***
#
# # 1.Dataset Name:Energy Consumption Forecasting
# # 2.source:https://www.kaggle.com/datasets/taruneshburman/energy-consumption-forecasting
# # 3.FileFormat:csv

# %%
import pandas as pd
import pandas as df # Corrected typo: 'dataframe' changed to 'pandas'

# %%
df=pd.read_csv('/content/sample_data/Energy_Consumption_Forecasting.csv')

# %%
df.head()
# Out:
#    Solar Irradiance (kWh/m²)  Average Temperature (°C)  Wind Speed (m/s)  \
# 0                   3.745401                 -0.743354          3.925585
# 1                   9.507143                 17.095047          3.704682
# 2                   7.319939                 33.647292         13.593819
# 3                   5.986585                 26.611244          3.743193
# 4                   1.560186                 30.328057          4.079246
#
#    Humidity (%)  Cloud Cover (%)  Atmospheric Pressure (hPa)  \
# 0     70.543269        57.199588                  989.363552
# 1     81.701326        80.543233                  997.343566
# 2     32.542111        76.016093                 1035.454739
# 3     66.238669        15.389990                  984.000439
# 4     61.457138        14.924947                 1036.964968
#
#    Daily Sunshine Duration (hours)  Panel Orientation (degrees)  \
# 0                         7.779083                    13.967804
# 1                         2.068636                    67.238110
# 2                        10.468735                   299.248490
# 3                         7.357395                   276.036608
# 4                         1.886447                   126.231369
#
#    System Efficiency (%) Type of Renewable System  Energy Consumption Category
# 0              74.824113                    Solar                            1
# 1              71.855470                     Wind                            2
# 2              18.617878                    Solar                            1
# 3              93.031516                     Wind                            2
# 4              61.162498                    Solar                            1

# %%
df.isnull().sum()
# Out:
# Solar Irradiance (kWh/m²)          0
# Average Temperature (°C)           0
# Wind Speed (m/s)                   0
# Humidity (%)                       0
# Cloud Cover (%)                    0
# Atmospheric Pressure (hPa)         0
# Daily Sunshine Duration (hours)    0
# Panel Orientation (degrees)        0
# System Efficiency (%)              0
# Type of Renewable System           0
# Energy Consumption Category        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Solar Irradiance (kWh/m²)        1000 non-null   float64
#  1   Average Temperature (°C)         1000 non-null   float64
#  2   Wind Speed (m/s)                 1000 non-null   float64
#  3   Humidity (%)                     1000 non-null   float64
#  4   Cloud Cover (%)                  1000 non-null   float64
#  5   Atmospheric Pressure (hPa)       1000 non-null   float64
#  6   Daily Sunshine Duration (hours)  1000 non-null   float64
#  7   Panel Orientation (degrees)      1000 non-null   float64
#  8   System Efficiency (%)            1000 non-null   float64
#  9   Type of Renewable System         1000 non-null   object
#  10  Energy Consumption Category      1000 non-null   int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 86.1+ KB

# %%
print(df.columns)
# Out:
# Index(['Solar Irradiance (kWh/m²)', 'Average Temperature (°C)',
#        'Wind Speed (m/s)', 'Humidity (%)', 'Cloud Cover (%)',
#        'Atmospheric Pressure (hPa)', 'Daily Sunshine Duration (hours)',
#        'Panel Orientation (degrees)', 'System Efficiency (%)',
#        'Type of Renewable System', 'Energy Consumption Category'],
#       dtype='object')

# %%
x=df.drop('Energy Consumption Category',axis=1)
y=df['Energy Consumption Category']

# %%
x
# Out:
#      Solar Irradiance (kWh/m²)  Average Temperature (°C)  Wind Speed (m/s)  \
# 0                     3.745401                 -0.743354          3.925585
# 1                     9.507143                 17.095047          3.704682
# 2                     7.319939                 33.647292         13.593819
# 3                     5.986585                 26.611244          3.743193
# 4                     1.560186                 30.328057          4.079246
# ..                         ...                       ...               ...
# 995                   0.915821                 22.847758         12.979436
# 996                   9.173136                 37.830731          2.359098
# 997                   1.368186                 -6.552099          4.646818
# 998                   9.502374                 -7.147264          4.350683
# 999                   4.460058                  4.109354         13.071211
#
#      Humidity (%)  Cloud Cover (%)  Atmospheric Pressure (hPa)  \
# 0       70.543269        57.199588                  989.363552
# 1       81.701326        80.543233                  997.343566
# 2       32.542111        76.016093                 1035.454739
# 3       66.238669        15.389990                  984.000439
# 4       61.457138        14.924947                 1036.964968
# ..            ...              ...                         ...
# 995     49.789633        89.739732                 1018.443536
# 996     40.096106        11.938101                 1000.322041
# 997     45.511508        32.784284                 1026.514885
# 998     57.694653        81.574538                  998.529063
# 999     24.523062        59.731238                  964.938164
#
#      Daily Sunshine Duration (hours)  Panel Orientation (degrees)  \
# 0                           7.779083                    13.967804
# 1                           2.068636                    67.238110
# 2                          10.468735                   299.248490
# 3                           7.357395                   276.036608
# 4                           1.886447                   126.231369
# ..                               ...                          ...
# 995                         6.956845                    98.337463
# 996                         8.004442                    75.426921
# 997                        10.938923                   163.918350
# 998                         4.147442                   327.037517
# 999                         7.458088                    37.612914
#
#      System Efficiency (%) Type of Renewable System
# 0                74.824113                    Solar
# 1                71.855470                     Wind
# 2                18.617878                    Solar
# 3                93.031516                     Wind
# 4                61.162498                    Solar
# ..                     ...                      ...
# 995              56.343655                    Solar
# 996              24.883338                    Solar
# 997              97.994153                     Wind
# 998              19.713210                    Solar
# 999              93.874973                     Wind
#
# [1000 rows x 10 columns]

# %%
y
# Out:
# 0      1
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 995    0
# 996    1
# 997    1
# 998    0
# 999    0
# Name: Energy Consumption Category, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_Test,y_train,y_Test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Solar Irradiance (kWh/m²)  Average Temperature (°C)  Wind Speed (m/s)  \
# 29                    0.464504                 31.445774          9.812619
# 535                   9.447657                 -3.905695         12.512169
# 695                   6.106200                 -6.591385          7.785484
# 557                   0.287827                 10.551423          4.493485
# 836                   9.148459                 -3.595213         14.898825
# ..                         ...                       ...               ...
# 106                   4.103829                  9.812101         12.857689
# 270                   8.093612                 24.749094          1.563372
# 860                   7.755276                 28.822372         13.001555
# 435                   7.009691                 -8.501321          5.842228
# 102                   3.143560                 34.189294          2.369322
#
#      Humidity (%)  Cloud Cover (%)  Atmospheric Pressure (hPa)  \
# 29      66.905394        36.047451                  962.130300
# 535     21.671108        58.799163                  960.431309
# 695     12.709349        87.991463                  980.946258
# 557     53.905089        67.906660                 1023.592041
# 836     93.929939        37.736318                 1038.659544
# ..            ...              ...                         ...
# 106     75.110304        96.530272                  986.679832
# 270     32.794515        64.876539                  969.267640
# 860     83.320390        62.543345                  995.539491
# 435     45.030742        28.060081                 1023.958118
# 102     92.309380        54.814520                 1007.090705
#
#      Daily Sunshine Duration (hours)  Panel Orientation (degrees)  \
# 29                          1.213987                    54.802157
# 535                         3.004305                   252.465603
# 695                         8.890598                   244.124101
# 557                         0.635231                   182.843070
# 836                         4.399652                   218.051727
# ..                               ...                          ...
# 106                         5.916362                    10.148883
# 270                         4.200082                   115.456379
# 860                         0.862881                    19.919659
# 435                         6.745737                   322.828758
# 102                         3.830704                   345.248703
#
#      System Efficiency (%) Type of Renewable System
# 29               82.548707                     Wind
# 535              39.150600                    Solar
# 695              64.518354                    Solar
# 557              63.433520                     Wind
# 836              55.276149                     Wind
# ..                     ...                      ...
# 106              27.868857                     Wind
# 270              40.822770                    Solar
# 860              55.516807                     Wind
# 435              32.207268                     Wind
# 102              44.996635                    Solar
#
# [800 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression
